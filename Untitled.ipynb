# %%
# %run problem1.py
# Out:
# Analysis for Γ₀ = 0.100:
# Critical coupling value: 0.150
# Expected state: NOT PHASE-LOCKED
# Not expected to phase-lock (Γ₀ = 0.100 < critical value 0.150)
# Analysis for Γ₀ = 0.150:
# Critical coupling value: 0.150
# Expected state: NOT PHASE-LOCKED
# Not expected to phase-lock (Γ₀ = 0.150 < critical value 0.150)
# Critical coupling value for phase-locking: 0.150

# %%
# %run problem2.py
# Out:
# Simulating 1D chain with Γ₀ = 0.1
# Simulating 1D chain with Γ₀ = 1
