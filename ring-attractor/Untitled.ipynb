# %%
# %run initialize_model.py
# Out:
# Model Parameters:
#   N: 1000
#   W0: -1
#   W1: 3
#   dt: 0.01
#   Tmax: 1000
#   Tinput: 500
#   I0: 2
#   sigma: 0.5
#   phi0: 0
#
# First 10 neuron angles (radians):
# [0.         0.00628319 0.01256637 0.01884956 0.02513274 0.03141593
#  0.03769911 0.0439823  0.05026548 0.05654867]
#
# Connectivity matrix shape:
# (1000, 1000)
#
# Initial firing rates (first 10 values):
# [-0.00909563 -0.00605838 -0.00363407 -0.00026881  0.00396961  0.00374701
#  -0.00195645  0.0047297  -0.00168727  0.00329255]

# %%
# %run simulate_model.py
# Out:
# Final firing rates (first 10 neurons):
# [0.07103007 0.07128033 0.07152419 0.0717623  0.07199449 0.0722214
#  0.07244186 0.07265623 0.0728642  0.07306666]

# %%
# %run plot_analysis.py

# %%
# %run sweep_w1.py
